# %%
from typing import List, Dict, Any, Optional
import json, re
from decimal import Decimal, InvalidOperation
from pprint import pprint as pp

# %%
def is_blank_or_na(v: Any) -> bool:
    if not isinstance(v, str):
        return False
    v = v.strip().lower()
    return v in {"", "na", "na.", "n/a", "n/a.", "n.a", "n.a."}


def iter_dict_rows(records):
    """Yield dict rows even if they live inside nested lists."""
    for r in records:
        if isinstance(r, dict):
            yield r
        elif isinstance(r, list):
            yield from iter_dict_rows(r)
        # ignore anything else


def parse_quantity(s: Any) -> Optional[Decimal]:
    if not isinstance(s, str) or is_blank_or_na(s) or 'line' in s:
        return None

    m = re.search(r'(\d[\d,]*\.?\d*)\s*Kg', s, re.I)
    if m:
        try:
            return Decimal(m.group(1).replace(',', ''))
        except InvalidOperation:
            pass

    m = re.search(r'(\d[\d,]*\.?\d*)', s.strip())
    if not m:
        return None
    try:
        return Decimal(m.group(1).replace(',', ''))
    except InvalidOperation:
        return None

def find_col(records: List[Dict[str, Any]], syns: List[str]) -> Optional[str]:
    for s in syns:
        if any(isinstance(r, dict) and s in r for r in records):
            return s
    return None


TOL = Decimal("0.001")

def extract_trolley_spec(records):
    bags = trays = min_load = None

    for row in records:
        if "Number of bags per tray" in row:
            if not is_blank_or_na(row["Number of bags per tray"]):
                bags = parse_quantity(row["Number of bags per tray"])

        if "No of trays per trolley" in row:
            if not is_blank_or_na(row["No of trays per trolley"]):
                trays = parse_quantity(row["No of trays per trolley"])

        if "Minimum load (One trolley)" in row:
            if not is_blank_or_na(row["Minimum load (One trolley)"]):
                min_load = parse_quantity(row["Minimum load (One trolley)"])

    if bags is None or trays is None or min_load is None:
        return None

    try:
        max_load = bags * trays
    except Exception:
        return None

    return {
        "min_load": min_load,
        "max_load": max_load
    }

def trolley_load_anomalies_for_page(records, spec):
    min_load = spec["min_load"]
    max_load = spec["max_load"]

    anomalies = []
    qty_keys = ["Quantity Nos. Bags", "Quantity Nos. Bag", "Quantity Bags"]

    def get_qty(row):
        for k in qty_keys:
            if k in row:
                return parse_quantity(row.get(k))
        return None

    for row in records:
        if "Trolley" not in row:
            continue

        trolley_name = str(row.get("Trolley", "")).strip()
        if trolley_name.lower() == "bags for sensor placement":
            continue

        qty = get_qty(row)
        if qty is None:
            continue

        if qty < min_load or qty > max_load:
            anomalies.append({
                "parameter": f"Trolley Load — {trolley_name}",
                "observed_value": float(qty),
                "standard_range": f"{float(min_load)} to {float(max_load)} Bags"
            })

    return anomalies

def anomalies_for_page(records, req_syns, obs_syns, trolley_spec=None):

    flat = list(iter_dict_rows(records))
    if not flat:
        return []

    req_col = find_col(flat, req_syns)
    obs_col = find_col(flat, obs_syns)

    # If no standard/observed columns, do only trolley check
    if not req_col or not obs_col:
        return trolley_spec and trolley_load_anomalies_for_page(flat, trolley_spec) or []

    out = []

    for row in flat:
        std = parse_quantity(row.get(req_col))
        obs = parse_quantity(row.get(obs_col))
        if std is None or obs is None:
            continue

        item = str(row.get("Item", ""))

        # Rule 1: Twist-off port
        if "twist-off port" in item.lower():
            if std != obs:
                out.append({
                    "parameter": f"Quantity Dispensed — {row.get('Item','N/A')}",
                    "observed_value": int(obs),
                    "standard_range": f"== {int(std)} Nos."
                })
            continue

        # Rule 2: Material
        if "Material" in row:
            if std != obs:
                out.append({
                    "parameter": f"Issued Qty — {row.get('Material','N/A')}",
                    "observed_value": float(obs),
                    "standard_range": f"== {float(std)}"
                })
            continue

        # Rule 3: Ingredients
        if "Ingredients" in row:
            if abs(std - obs) > TOL:
                out.append({
                    "parameter": f"Quantity Dispensed — {row.get('Ingredients','N/A')}",
                    "observed_value": float(obs),
                    "standard_range": f"== {float(std)} (±{float(TOL)})"
                })
            continue

        # Fallback
        if std != obs:
            out.append({
                "parameter": f"Quantity Dispensed — "
                            f"{row.get('Item') or row.get('Material') or row.get('Ingredients') or 'N/A'}",
                "observed_value": float(obs),
                "standard_range": f"== {float(std)}"
            })

    # Add trolley anomalies
    if trolley_spec:
        out.extend(trolley_load_anomalies_for_page(flat, trolley_spec))

    return out

def quant_variance_check(bmr_data: Dict[str, Any], keys: List[List[str]]) -> List[Dict[str, Any]]:

    req_syns, obs_syns = keys[0], keys[1]

    trolley_spec = None
    trolley_spec_next_page_allowed = False
    results = []
    for page_no, page in bmr_data.items():
        # print(f'---------------{page_no}-------------------')
        records = page.get("records", [])
        flat = list(iter_dict_rows(records))
        # print('------------------------')
    
        # ---- Extract trolley spec for this page ----
        new_spec = extract_trolley_spec(flat)
        # print(new_spec)
    
        if new_spec:
            trolley_spec = new_spec
            trolley_spec_next_page_allowed = True
        else:
            if trolley_spec_next_page_allowed:
                trolley_spec_next_page_allowed = False
            else:
                trolley_spec = None

        # ---- Run anomaly checks ----
        anoms = anomalies_for_page(flat, req_syns, obs_syns, trolley_spec)
    
        has = 1 if anoms else 0

        results.append({
            "page_no": page_no,
            "section_name": "Process Parameters",
            "check_name": "Quantity Variance Check",
            "anomaly_status": has
            })
    return results

# %%
if __name__ == "__main__":
    # filepath = '../JSON/BMR_61_FLATTEN.json'
    filepath = '../JSON/test.json'

    with open(filepath, "r", encoding="utf-8") as f:
        data = json.load(f)
    k1 = ['Qty. Required', 'Quantity Req.', 'Quantity Required']
    k2 = ['Dispensed', 'Issued Qty', 'Quantity Dispensed']
    results = quant_variance_check(data, [k1, k2])

# %%
pp(results)
# Out:
# [{'anomaly_status': 1,
#   'check_name': 'Quantity Variance Check',
#   'page_no': '31',
#   'section_name': 'Process Parameters'},
#  {'anomaly_status': 1,
#   'check_name': 'Quantity Variance Check',
#   'page_no': '114',
#   'section_name': 'Process Parameters'},
#  {'anomaly_status': 1,
#   'check_name': 'Quantity Variance Check',
#   'page_no': '115',
#   'section_name': 'Process Parameters'}]

# %%
pp(data)
# Out:
# {'113': {'BATCH NO.': 'AH250061',
#          'BATCH SIZE': '4000 L/ 3960 kg/7606 Units',
#          'BMR NO.': 'BMR-PA-048-10',
#          'NAME OF PRODUCT': 'Multiple Electrolytes Injection Type 1 USP',
#          'PAGE NO.': 'Page 111 of 145',
#          'additional_copy': False,
#          'balance_id': '',
#          'batch_number': '',
#          'date': '',
#          'end_time': '',
#          'error': [],
#          'markdown_page': "<a id='bff3082c-2120-48ab-9a7f-23f927aa0b4e'></a> "
#                           '<::attestation: Stamp Status: Master Copy Readable '
#                           'Text: MASTER COPY Short description of visual '
#                           'elements and positioning: A red rectangular stamp '
#                           'with bold text, slightly tilted, centered on the '
#                           'image.::> <a '
#                           "id='ad1a52fc-2fc4-4e2f-95bc-67cdbe7c1d71'></a> "
#                           '<table id="0-1"> <tr><td id="0-2">amneal '
#                           '(logo)</td><td id="0-3" colspan="2">BATCH '
#                           'MANUFACTURING RECORD</td></tr> <tr><td '
#                           'id="0-4">NAME OF PRODUCT</td><td id="0-5">Multiple '
#                           'Electrolytes Injection Type 1 USP</td><td '
#                           'id="0-6">BATCH NO.</td></tr> <tr><td id="0-7">BMR '
#                           'NO.</td><td id="0-8">BMR-PA-048-10</td><td id="0-9" '
#                           'rowspan="3"></td></tr> <tr><td id="0-a">BATCH '
#                           'SIZE</td><td id="0-b">4000 L/ 3960 kg/7606 '
#                           'Units</td></tr> <tr><td id="0-c">PAGE NO.</td><td '
#                           'id="0-d">Page 111 of 145</td></tr> </table> <a '
#                           "id='7e5ee004-a1c2-4792-9554-607c3127ce0d'></a> "
#                           '<table id="0-e"> <tr><td id="0-f">19.0</td><td '
#                           'id="0-g">FILLING LINE PROCESS</td></tr> <tr><td '
#                           'id="0-h" colspan="2">After completion of online '
#                           'checkweigher operation, collect all the rejected '
#                           'units from rejection bin and re-pass the rejected '
#                           'units again from the checkweigher system. Record '
#                           'the details of Online Check weigher with conveyor '
#                           'belt with drop out rejector (Re-pass the rejected '
#                           'units) in below table:</td></tr> </table> <table '
#                           'id="0-i"> <tr><td id="0-j">Date</td><td '
#                           'id="0-k">Start Time</td><td id="0-l">End '
#                           'Time</td><td id="0-m">Done by (SM)</td><td '
#                           'id="0-n">Checked by (SM)</td></tr> <tr><td '
#                           'id="0-o"></td><td id="0-p"></td><td id="0-q">(gray '
#                           'rectangle)</td><td id="0-r"></td><td '
#                           'id="0-s"></td></tr> <tr><td id="0-t"></td><td '
#                           'id="0-u">(gray rectangle)</td><td id="0-v"></td><td '
#                           'id="0-w"></td><td id="0-x"></td></tr> </table> <a '
#                           "id='69e2af77-5cae-48fc-af6b-8d9ebe5b4861'></a> "
#                           '<table id="0-y"> <tr><td id="0-z" colspan="4">From '
#                           'Checkweigher Report Printout (repass)</td></tr> '
#                           '<tr><td id="0-A">No. of Rejected Bags for Repass '
#                           '(D)</td><td id="0-B">No of Bag rejected after '
#                           'repassing (E)</td><td id="0-C">No. of Good/Ok Bag '
#                           'after repassing (F)</td><td id="0-D">Total good/ok '
#                           'bags G=C+F</td></tr> <tr><td id="0-E"></td><td '
#                           'id="0-F"></td><td id="0-G"></td><td '
#                           'id="0-H"></td></tr> </table> <table id="0-I"> '
#                           '<tr><td id="0-J">Recorded By (SM):</td><td '
#                           'id="0-K">Verified By (SM):</td></tr> </table> <a '
#                           "id='85edfa5f-a00f-4085-b71a-da6cda011f00'></a> "
#                           '<table id="0-L"> <tr><td id="0-M">Total good/ok '
#                           'bags (G)</td><td id="0-N" colspan="2">Bags used '
#                           'Post challenge test + Bag used for challenge test '
#                           'during breakdown / power failure (if any) '
#                           '(H)</td><td id="0-O">No. of Good/Ok bag after '
#                           'online check weighing activity (I = G - '
#                           'H)</td></tr> <tr><td id="0-P"></td><td id="0-Q" '
#                           'colspan="2"></td><td id="0-R"></td></tr> <tr><td '
#                           'id="0-S" colspan="2">Recorded By (SM):</td><td '
#                           'id="0-T" colspan="2">Verified By (SM):</td></tr> '
#                           '</table> <a '
#                           "id='7489ca7f-6f58-4eeb-93e3-143238b57d0b'></a> "
#                           '<::attestation: Official Stamp\\nStatus: '
#                           'Superseded\\nReadable Text: SUPERSEDED COPY\\nA red '
#                           'rectangular stamp with the text "SUPERSEDED" above '
#                           '"COPY", positioned centrally in the image.::>',
#          'master_copy': True,
#          'previous_batch_number': '',
#          'previous_product': '',
#          'qa_authorized': True,
#          'qa_sign_date': '',
#          'receipe_id': '',
#          'records': [{'Checked by (SM)': 'PW10-Apr-25',
#                       'Date': '10-Apr-25',
#                       'Done by (SM)': 'Anz 1-Apr-25 (signature)',
#                       'End Time': '',
#                       'Start Time': '15! 43'},
#                      {'Checked by (SM)': 'Pr10-Apr-25',
#                       'Date': '10-Apr-25',
#                       'Done by (SM)': 'doradzi 10-Apr-25 (signature)',
#                       'End Time': '15:44',
#                       'Start Time': ''},
#                      [{'No of Bag rejected after repassing (E)': '00',
#                        'No. of Good/Ok Bag after repassing (F)': '26',
#                        'No. of Rejected Bags for Repass (D)': '26',
#                        'Total good/ok bags G=C+F': '7439'}],
#                      [{'Bags used Post challenge test + Bag used for challenge test during breakdown / power failure (if any) (H)': '02',
#                        'No. of Good/Ok bag after online check weighing activity (I = G - H)': '7437',
#                        'Total good/ok bags (G)': '7439'}]],
#          'reference_copy': False,
#          'room_no': '',
#          'rules_or_instructions': ['19.0',
#                                    'FILLING LINE PROCESS',
#                                    'After completion of online checkweigher '
#                                    'operation, collect all the rejected units '
#                                    'from rejection bin and re-pass the '
#                                    'rejected units again from the checkweigher '
#                                    'system. Record the details of Online Check '
#                                    'weigher with conveyor belt with drop out '
#                                    'rejector (Re-pass the rejected units) in '
#                                    'below table:',
#                                    'From Checkweigher Report Printout '
#                                    '(repass)'],
#          'start_time': '',
#          'superseded_copy': {'qa_sign_date': '', 'superseded_copy': False}},
#  '114': {'BATCH NO.': 'AH250061',
#          'BATCH SIZE': '4000 L/ 3960 kg/7606 Units',
#          'BMR NO.': 'BMR-PA-048-10',
#          'NAME OF PRODUCT': 'Multiple Electrolytes Injection Type 1 USP',
#          'PAGE NO.': 'Page 112 of 145',
#          'additional_copy': False,
#          'balance_id': '',
#          'batch_number': '',
#          'date': '',
#          'end_time': '',
#          'error': [],
#          'markdown_page': "<a id='5b9a8454-5144-4a52-bdcd-f32c8deff96f'></a> "
#                           '<::attestation: Official Stamp Status: Master Copy '
#                           'Readable Text: MASTER COPY A red rectangular stamp '
#                           'with the text "MASTER COPY" inside, positioned '
#                           'centrally in the image. ::> <a '
#                           "id='3d490224-c59b-4c34-bc57-1bfe8a1d2365'></a> "
#                           '<table id="0-1"> <tr><td id="0-2">amneal '
#                           '(logo)</td><td id="0-3" colspan="2">BATCH '
#                           'MANUFACTURING RECORD</td></tr> <tr><td '
#                           'id="0-4">NAME OF PRODUCT</td><td id="0-5">Multiple '
#                           'Electrolytes Injection Type 1 USP</td><td '
#                           'id="0-6">BATCH NO.</td></tr> <tr><td id="0-7">BMR '
#                           'NO.</td><td id="0-8">BMR-PA-048-10</td><td id="0-9" '
#                           'rowspan="3"></td></tr> <tr><td id="0-a">BATCH '
#                           'SIZE</td><td id="0-b">4000 L/ 3960 kg/7606 '
#                           'Units</td></tr> <tr><td id="0-c">PAGE NO.</td><td '
#                           'id="0-d">Page 112 of 145</td></tr> </table> <a '
#                           "id='bb57ea58-bb87-4fd0-8cf2-76c8fe519cba'></a> "
#                           '<table id="0-e"> <tr><td id="0-f">19.0</td><td '
#                           'id="0-g">FILLING LINE PROCESS</td></tr> <tr><td '
#                           'id="0-h" colspan="2">Record the details of Bag '
#                           'collection in below table:</td></tr> </table> '
#                           '<table id="0-i"> <tr><td id="0-j">Date</td><td '
#                           'id="0-k">Start Time</td><td id="0-l">End '
#                           'Time</td><td id="0-m">Done by (SM)</td><td '
#                           'id="0-n">Checked by(SM)</td></tr> <tr><td '
#                           'id="0-o"></td><td id="0-p"></td><td '
#                           'id="0-q">(visual only) gray square</td><td '
#                           'id="0-r"></td><td id="0-s"></td></tr> <tr><td '
#                           'id="0-t"></td><td id="0-u"></td><td '
#                           'id="0-v"></td><td id="0-w"></td><td '
#                           'id="0-x"></td></tr> </table> <a '
#                           "id='20eb23c8-761a-4e37-9962-e17a617247b0'></a> "
#                           '<table id="0-y"> <tr><td id="0-z" colspan="2">Total '
#                           'Bags available for TS.</td></tr> <tr><td '
#                           'id="0-A">Number of bags per tray</td><td '
#                           'id="0-B">16</td></tr> <tr><td id="0-C">No of trays '
#                           'per trolley</td><td id="0-D">20</td></tr> <tr><td '
#                           'id="0-E">Minimum load (One trolley)</td><td '
#                           'id="0-F">160</td></tr> </table> <a '
#                           "id='398e4f06-d9cb-42c4-811f-5dd5d224637e'></a> "
#                           '<table id="0-G"> <tr><td id="0-H">Lot No.</td><td '
#                           'id="0-I">Trolley</td><td id="0-J">Quantity Nos. '
#                           'Bags</td><td id="0-K">Calculated By (SM)</td></tr> '
#                           '<tr><td id="0-L" rowspan="5">LOT-A</td><td '
#                           'id="0-M">Trolley 1</td><td id="0-N"></td><td '
#                           'id="0-O"></td></tr> <tr><td id="0-P">Trolley '
#                           '2</td><td id="0-Q"></td><td id="0-R"></td></tr> '
#                           '<tr><td id="0-S">Trolley 3</td><td '
#                           'id="0-T"></td><td id="0-U"></td></tr> <tr><td '
#                           'id="0-V">Trolley 4</td><td id="0-W"></td><td '
#                           'id="0-X"></td></tr> <tr><td id="0-Y">Bags for '
#                           'Sensor placement</td><td id="0-Z"></td><td '
#                           'id="0-10"></td></tr> <tr><td id="0-11" '
#                           'rowspan="5">LOT-B</td><td id="0-12">Trolley '
#                           '1</td><td id="0-13"></td><td id="0-14"></td></tr> '
#                           '<tr><td id="0-15">Trolley 2</td><td '
#                           'id="0-16"></td><td id="0-17"></td></tr> <tr><td '
#                           'id="0-18">Trolley 3</td><td id="0-19"></td><td '
#                           'id="0-1a"></td></tr> <tr><td id="0-1b">Trolley '
#                           '4</td><td id="0-1c"></td><td id="0-1d"></td></tr> '
#                           '<tr><td id="0-1e">Bags for Sensor placement</td><td '
#                           'id="0-1f"></td><td id="0-1g"></td></tr> <tr><td '
#                           'id="0-1h" rowspan="5">LOT-C</td><td '
#                           'id="0-1i">Trolley 1</td><td id="0-1j"></td><td '
#                           'id="0-1k"></td></tr> <tr><td id="0-1l">Trolley '
#                           '2</td><td id="0-1m"></td><td id="0-1n"></td></tr> '
#                           '<tr><td id="0-1o">Trolley 3</td><td '
#                           'id="0-1p"></td><td id="0-1q"></td></tr> <tr><td '
#                           'id="0-1r">Trolley 4</td><td id="0-1s"></td><td '
#                           'id="0-1t"></td></tr> <tr><td id="0-1u">Bags for '
#                           'Sensor placement</td><td id="0-1v"></td><td '
#                           'id="0-1w"></td></tr> </table> <a '
#                           "id='0a356daa-1095-409c-b121-206b1b37f372'></a> "
#                           '<::attestation: Official Stamp Status: Superseded '
#                           'Readable Text: SUPERSEDED COPY A rectangular red '
#                           'stamp with the text "SUPERSEDED COPY" centered '
#                           'within it::>',
#          'master_copy': True,
#          'previous_batch_number': '',
#          'previous_product': '',
#          'qa_authorized': True,
#          'qa_sign_date': '',
#          'receipe_id': '',
#          'records': [{'Checked by(SM)': 'Pr10-Apr-25 (signature)',
#                       'Date': '10-Apr-25',
#                       'Done by (SM)': 'dm 10-Apr-25.',
#                       'End Time': '',
#                       'Start Time': '04:41'},
#                      {'Checked by(SM)': 'Dee-Apr-25 (signature)',
#                       'Date': '10-Apr-25',
#                       'Done by (SM)': 'Hemky 10-Apr-25',
#                       'End Time': '15:44',
#                       'Start Time': ''},
#                      [{'Minimum load (One trolley)': None,
#                        'No of trays per trolley': 'Trolley 1',
#                        'Number of bags per tray': '320'}],
#                      [{'Calculated By (SM)': '',
#                        'Lot No.': 'LOT-A',
#                        'Quantity Nos. Bags': '',
#                        'Trolley': 'Trolley 1'},
#                       {'Calculated By (SM)': '',
#                        'Lot No.': 'LOT-A',
#                        'Quantity Nos. Bags': '',
#                        'Trolley': 'Trolley 2'},
#                       {'Calculated By (SM)': '',
#                        'Lot No.': 'LOT-A',
#                        'Quantity Nos. Bags': '',
#                        'Trolley': 'Trolley 3'},
#                       {'Calculated By (SM)': '',
#                        'Lot No.': 'LOT-A',
#                        'Quantity Nos. Bags': '',
#                        'Trolley': 'Trolley 4'},
#                       {'Calculated By (SM)': '',
#                        'Lot No.': 'LOT-A',
#                        'Quantity Nos. Bags': '',
#                        'Trolley': 'Bags for Sensor placement'},
#                       {'Calculated By (SM)': '',
#                        'Lot No.': 'LOT-B',
#                        'Quantity Nos. Bags': '',
#                        'Trolley': 'Trolley 1'},
#                       {'Calculated By (SM)': '',
#                        'Lot No.': 'LOT-B',
#                        'Quantity Nos. Bags': '',
#                        'Trolley': 'Trolley 2'},
#                       {'Calculated By (SM)': '',
#                        'Lot No.': 'LOT-B',
#                        'Quantity Nos. Bags': '',
#                        'Trolley': 'Trolley 3'},
#                       {'Calculated By (SM)': '',
#                        'Lot No.': 'LOT-B',
#                        'Quantity Nos. Bags': '',
#                        'Trolley': 'Trolley 4'},
#                       {'Calculated By (SM)': '',
#                        'Lot No.': 'LOT-B',
#                        'Quantity Nos. Bags': '',
#                        'Trolley': 'Bags for Sensor placement'},
#                       {'Calculated By (SM)': '',
#                        'Lot No.': 'LOT-C',
#                        'Quantity Nos. Bags': '',
#                        'Trolley': 'Trolley 1'},
#                       {'Calculated By (SM)': '',
#                        'Lot No.': 'LOT-C',
#                        'Quantity Nos. Bags': '',
#                        'Trolley': 'Trolley 2'},
#                       {'Calculated By (SM)': '',
#                        'Lot No.': 'LOT-C',
#                        'Quantity Nos. Bags': '',
#                        'Trolley': 'Trolley 3'},
#                       {'Calculated By (SM)': '',
#                        'Lot No.': 'LOT-C',
#                        'Quantity Nos. Bags': '',
#                        'Trolley': 'Trolley 4'},
#                       {'Calculated By (SM)': '',
#                        'Lot No.': 'LOT-C',
#                        'Quantity Nos. Bags': '',
#                        'Trolley': 'Bags for Sensor placement'}]],
#          'reference_copy': False,
#          'room_no': '',
#          'rules_or_instructions': ['For Challenge Study',
#                                    '19.0 FILLING LINE PROCESS',
#                                    'Record the details of Bag collection in '
#                                    'below table:',
#                                    'Total Bags available for TS.'],
#          'start_time': '',
#          'superseded_copy': {'qa_sign_date': '', 'superseded_copy': False}},
#  '31': {'BATCH NO.': 'AH250061',
#         'BATCH SIZE': '4000 L/3960 kg/7606 Units',
#         'BMR NO.': 'BMR-PA-048-10',
#         'NAME OF PRODUCT': 'Multiple Electrolytes Injection Type 1 USP',
#         'PAGE NO.': 'Page 30 of 145',
#         'additional_copy': False,
#         'balance_id': '',
#         'batch_number': '',
#         'bmr_issued_by_QA': {'authorized_copy': None, 'qa_sign_date': ''},
#         'date': '',
#         'end_time': '08-APR-25, 14:09',
#         'error': [],
#         'markdown_page': "<a id='c6306d25-b1a9-4922-b374-88ada484730c'></a> "
#                          '<::attestation: Stamp Master Copy Readable Text: '
#                          'MASTER COPY A rectangular red stamp with textured '
#                          'edges, centrally located.::> <a '
#                          "id='b07ee2f2-b289-4550-a650-2485240e9b7f'></a> "
#                          '<table id="0-1"> <tr><td id="0-2">amneal '
#                          '(logo)</td><td id="0-3" colspan="2">BATCH '
#                          'MANUFACTURING RECORD</td></tr> <tr><td id="0-4">NAME '
#                          'OF PRODUCT</td><td id="0-5">Multiple Electrolytes '
#                          'Injection Type 1 USP</td><td id="0-6">BATCH '
#                          'NO.</td></tr> <tr><td id="0-7">BMR NO.</td><td '
#                          'id="0-8">BMR-PA-048-10</td><td id="0-9" '
#                          'rowspan="3"></td></tr> <tr><td id="0-a">BATCH '
#                          'SIZE</td><td id="0-b">4000 L/ 3960 kg/7606 '
#                          'Units</td></tr> <tr><td id="0-c">PAGE NO.</td><td '
#                          'id="0-d">Page 30 of 145</td></tr> </table> <a '
#                          "id='601e2c4f-949e-432d-b9bd-d063e9e3e573'></a> "
#                          '<table><thead><tr><th>10.0</th><th>RAW MATERIAL '
#                          'DISPENSING</th></tr></thead><tbody><tr><td '
#                          'colspan="2">(AS PER SOP: Dispensing of Raw Material, '
#                          'SOP No. PAP-SM-008)</td></tr><tr><td '
#                          'colspan="2">Note: Fill the check list for line '
#                          'clearance as per SOP No.: PAP-QA-002 for dispensing '
#                          'area and attach with BMR. Dispensing Start Date and '
#                          'Time: ___</td></tr></tbody></table> <a '
#                          "id='28f227dd-7040-4e59-b6ea-9c7a9e7debf7'></a> "
#                          '<table id="0-e"> <tr><td id="0-f">Sr. No.</td><td '
#                          'id="0-g">Ingredients</td><td id="0-h">Material '
#                          'code</td><td id="0-i">A.R. No.</td><td '
#                          'id="0-j">Balance ID</td><td id="0-k">Qty. '
#                          'Required</td><td id="0-l">Quantity Dispensed</td><td '
#                          'id="0-m">Done By (SM/ MM) (Sign/ Date)</td><td '
#                          'id="0-n">Ckd. by (SM) (Sign/ Date)</td></tr> <tr><td '
#                          'id="0-o" rowspan="2">1.</td><td id="0-p" '
#                          'rowspan="2">Sodium Chloride IP</td><td id="0-q" '
#                          'rowspan="2">RMI-0370</td><td id="0-r" '
#                          'rowspan="2"></td><td id="0-s" rowspan="2"></td><td '
#                          'id="0-t">Kg#</td><td id="0-u" rowspan="2"></td><td '
#                          'id="0-v" rowspan="2"></td><td id="0-w" '
#                          'rowspan="2"></td></tr> <tr><td id="0-x">Recorded '
#                          'by:</td></tr> <tr><td id="0-y" '
#                          'rowspan="2">2.</td><td id="0-z" rowspan="2">Sodium '
#                          'Gluconate</td><td id="0-A" '
#                          'rowspan="2">RMI-0445</td><td id="0-B" '
#                          'rowspan="2"></td><td id="0-C" rowspan="2">empty '
#                          'white rectangle</td><td id="0-D">Kg#</td><td '
#                          'id="0-E" rowspan="2"></td><td id="0-F" '
#                          'rowspan="2"></td><td id="0-G" rowspan="2">(empty '
#                          'white rectangle with red border)</td></tr> <tr><td '
#                          'id="0-H">Recorded by:</td></tr> <tr><td '
#                          'id="0-I">3.</td><td id="0-J">Sodium Acetate '
#                          'Trihydrate IP</td><td id="0-K">RMI-0391</td><td '
#                          'id="0-L"></td><td id="0-M"></td><td id="0-N">14.72 '
#                          'Kg</td><td id="0-O"></td><td id="0-P"></td><td '
#                          'id="0-Q"></td></tr> <tr><td id="0-R" '
#                          'rowspan="2">4.</td><td id="0-S" '
#                          'rowspan="2">Potassium Chloride IP</td><td id="0-T" '
#                          'rowspan="2">RMI-0369</td><td id="0-U" '
#                          'rowspan="2"></td><td id="0-V" rowspan="2"></td><td '
#                          'id="0-W">Kg#</td><td id="0-X" rowspan="2"></td><td '
#                          'id="0-Y" rowspan="2"></td><td id="0-Z" '
#                          'rowspan="2"></td></tr> <tr><td id="0-10">Recorded '
#                          'by:</td></tr> <tr><td id="0-11" '
#                          'rowspan="2">5.</td><td id="0-12" '
#                          'rowspan="2">Magnesium Chloride IP '
#                          'Hexahydrate</td><td id="0-13" '
#                          'rowspan="2">RMI-0373</td><td id="0-14" '
#                          'rowspan="2"></td><td id="0-15" rowspan="2"></td><td '
#                          'id="0-16">Kg#</td><td id="0-17" rowspan="2"></td><td '
#                          'id="0-18" rowspan="2"></td><td id="0-19" '
#                          'rowspan="2"></td></tr> <tr><td id="0-1a">Recorded '
#                          'by:</td></tr> <tr><td id="0-1b">6.</td><td '
#                          'id="0-1c">Sodium Hydroxide IP*</td><td '
#                          'id="0-1d">RMI-0389</td><td id="0-1e"></td><td '
#                          'id="0-1f"></td><td id="0-1g">4.0 g</td><td '
#                          'id="0-1h"></td><td id="0-1i"></td><td '
#                          'id="0-1j"></td></tr> </table> # Quantities in # will '
#                          'be displayed on reports and calculations. <a '
#                          "id='cc5d2d52-dfd6-4b59-b5e9-3aabb9115812'></a> # "
#                          'Quantity required will be dispensed based on potency '
#                          'calculation. Dispensing End Date and Time: '
#                          '__________ <a '
#                          "id='5193df37-b7bc-4044-88a9-52b08ce17b4d'></a> "
#                          '<::attestation: Official stamp Superseded SUPERSEDED '
#                          'COPY A red rectangular stamp with the text '
#                          '"SUPERSEDED COPY" is centrally placed.::>',
#         'master_copy': True,
#         'previous_batch_number': '',
#         'previous_product': '',
#         'qa_authorized': True,
#         'qa_sign_date': '',
#         'receipe_id': '',
#         'records': [{'A.R. No.': '2300 7409',
#                      'Balance ID': 'ERP/PI PRD/143',
#                      'Ckd. by (SM) (Sign/ Date)': '(signature) 08-Apr-25',
#                      'Done By (SM/ MM) (Sign/ Date)': '(signature) 08-APR-25',
#                      'Ingredients': 'Sodium Chloride IP',
#                      'Material code': 'RMI-0370',
#                      'Qty. Required': '25.364Kg# Recorded by: (signature) '
#                                       '08-APR-25',
#                      'Quantity Dispensed': '21.274 kg',
#                      'Sr. No.': '1.'},
#                     {'A.R. No.': '2300 4509',
#                      'Balance ID': 'ERP/PI PRD/143',
#                      'Ckd. by (SM) (Sign/ Date)': '(signature) 08-Apr-25',
#                      'Done By (SM/ MM) (Sign/ Date)': '(signature) 08-APR-25',
#                      'Ingredients': 'Sodium Gluconate',
#                      'Material code': 'RMI-0445',
#                      'Qty. Required': '20.126 Kg# Recorded by: (signature) '
#                                       '08-APR-25',
#                      'Quantity Dispensed': '4.700 kg 15.426 kg',
#                      'Sr. No.': '2.'},
#                     {'A.R. No.': '2300 4070',
#                      'Balance ID': 'ERP/PI PRD/143',
#                      'Ckd. by (SM) (Sign/ Date)': '(signature) 08-Apr-25',
#                      'Done By (SM/ MM) (Sign/ Date)': '(signature) 08-APR-25',
#                      'Ingredients': 'Sodium Acetate Trihydrate IP',
#                      'Material code': 'RMI-0391',
#                      'Qty. Required': '14.72 Kg',
#                      'Quantity Dispensed': '14.720 kg',
#                      'Sr. No.': '3.'},
#                     {'A.R. No.': '23000 4144',
#                      'Balance ID': 'ERP/PI PRD/143',
#                      'Ckd. by (SM) (Sign/ Date)': '(signature) 08-Apr-25',
#                      'Done By (SM/ MM) (Sign/ Date)': '(signature) 08-APR-25',
#                      'Ingredients': 'Potassium Chloride IP',
#                      'Material code': 'RMI-0369',
#                      'Qty. Required': '1.493 Kg# Recorded by: (signature) '
#                                       '08-APR-25',
#                      'Quantity Dispensed': '1.494 kg *',
#                      'Sr. No.': '4.'},
#                     {'A.R. No.': 'APM 2100059',
#                      'Balance ID': 'Explai PRO 1143',
#                      'Ckd. by (SM) (Sign/ Date)': '(signature) 08-Apr-24',
#                      'Done By (SM/ MM) (Sign/ Date)': '(signature) 08-APR-25',
#                      'Ingredients': 'Magnesium Chloride IP Hexahydrate',
#                      'Material code': 'RMI-0373',
#                      'Qty. Required': '1.202 Kg# Recorded by: (signature and '
#                                       'date)',
#                      'Quantity Dispensed': '1.202 kg',
#                      'Sr. No.': '5.'},
#                     {'A.R. No.': '1234 1234',
#                      'Balance ID': 'Eep/pil PRD MAJ',
#                      'Ckd. by (SM) (Sign/ Date)': '(signature) 08-Apr-25',
#                      'Done By (SM/ MM) (Sign/ Date)': '(signature) 08-APR-25',
#                      'Ingredients': 'Sodium Hydroxide IP*',
#                      'Material code': 'RMI-0389',
#                      'Qty. Required': '4.0 g',
#                      'Quantity Dispensed': '4.0000gm',
#                      'Sr. No.': '6.'}],
#         'reference_copy': False,
#         'room_no': '',
#         'rules_or_instructions': ['master_copy: True, qa_authorized: True, '
#                                   'reference_copy: False, additional_copy: '
#                                   'False, qa_sign_date: , previous_product: , '
#                                   'previous_batch_number: , batch_number: , '
#                                   'start_time: 08-APR-25, 11:31, end_time: '
#                                   '08-APR-25, 14:09, date: , room_no: , '
#                                   'balance_id: , receipe_id: , '
#                                   'rules_or_instructions: For Challenge Study; '
#                                   '10.0 RAW MATERIAL DISPENSING; (AS PER SOP: '
#                                   'Dispensing of Raw Material, SOP No. '
#                                   'PAP-SM-008); Note: Fill the check list for '
#                                   'line clearance as per SOP No.: PAP-QA-002 '
#                                   'for dispensing area and attach with BMR.; # '
#                                   'Quantity required will be dispensed based '
#                                   'on potency calculation.; * Material '
#                                   'Dispensed As per Balance Least count is '
#                                   '0.002kg, error:, superseded_copy: '
#                                   'superseded_copy: False, qa_sign_date: ',
#                                   None,
#                                   None,
#                                   None,
#                                   None,
#                                   None],
#         'start_time': '08-APR-25, 11:31',
#         'superseded_copy': {'qa_sign_date': None, 'superseded_copy': False}}}
